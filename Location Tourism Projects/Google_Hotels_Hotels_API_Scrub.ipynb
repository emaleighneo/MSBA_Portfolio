# %% [markdown]
# AZ Hotels

# %%
import requests
import json

# API key
api_key = "bcfbeaa7a45c637ab72fdfcd6562808f3e71766b34d9bf959c773cfd01f01872"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

# Loop through different cities
az_cities = ['Tuscon', 'Sahuarita', 'Catalina', 'Marana', 'Green Valley', 'Vail',
             'Oro Valley']
# Parameters for request
for city in az_cities:
  params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "api_key": api_key
  }

  response = requests.get(base_url, params=params)

# Convert response to JSON
  response_json = response.json()

# Print the JSON response with indentation and sorted keys for readability
  print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# Streaming output truncated to the last 5000 lines.
#             "hotel_class": "3-star hotel",
#             "images": [
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMu0e_5wpFe8NRHlXZEqiJ5kqEWEnTPjT2bGMQb=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMu0e_5wpFe8NRHlXZEqiJ5kqEWEnTPjT2bGMQb=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNkES6OvluYplvUDB_eDqitJNwnVUF0YZM3QxmZ=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNkES6OvluYplvUDB_eDqitJNwnVUF0YZM3QxmZ=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNCipV6o-Uc5wLk7VkVVzz4wj0IF89PEN3jwj-9=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNCipV6o-Uc5wLk7VkVVzz4wj0IF89PEN3jwj-9=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNwynJHGXo1-XrrO47TYwMLezihtma5tZRD-Syx=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNwynJHGXo1-XrrO47TYwMLezihtma5tZRD-Syx=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipPoPcC3uea-7glVFCakS0e8bQ4ogpoIqLm9xMW8=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPoPcC3uea-7glVFCakS0e8bQ4ogpoIqLm9xMW8=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMJIRxESYSmXg1hAUFhGASYOLkKuDVY8dI5E0tF=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMJIRxESYSmXg1hAUFhGASYOLkKuDVY8dI5E0tF=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipPueec0JIvohaPX489zWTMMuuhCsHsZRzjKMEsu=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPueec0JIvohaPX489zWTMMuuhCsHsZRzjKMEsu=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMOHn6puj1KUAZr53geHk-N-1qRNVHPt2JmNFle=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMOHn6puj1KUAZr53geHk-N-1qRNVHPt2JmNFle=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMezbNhakKmhyX55I10SiwZpgyqEw9SQPwQeUGK=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMezbNhakKmhyX55I10SiwZpgyqEw9SQPwQeUGK=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://www.hilton.com/en/hotels/egevcdt-highline-vail/?SEO_id=GMB-AMER-DT-EGEVCDT&y_source=1_ODYwMjU3OS03MTUtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D",
#             "location_rating": 3.6,
#             "name": "Highline Vail - a DoubleTree by Hilton",
#             "nearby_places": [
#                 {
#                     "name": "Vail Ski Resort",
#                     "transportations": [
#                         {
#                             "duration": "4 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "8 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "West Vail Mall - Westbound",
#                     "transportations": [
#                         {
#                             "duration": "5 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Aspen/Pitkin County Airport",
#                     "transportations": [
#                         {
#                             "duration": "1 hr 44 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "3 hr 27 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Westside Cafe & Market",
#                     "transportations": [
#                         {
#                             "duration": "1 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.2,
#             "property_token": "ChoIh8OzyoXq9PqOARoNL2cvMTFkZmgzNnJtMBAB",
#             "ratings": [
#                 {
#                     "count": 494,
#                     "stars": 5
#                 },
#                 {
#                     "count": 119,
#                     "stars": 4
#                 },
#                 {
#                     "count": 47,
#                     "stars": 3
#                 },
#                 {
#                     "count": 46,
#                     "stars": 2
#                 },
#                 {
#                     "count": 78,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 784,
#             "reviews_breakdown": [
#                 {
#                     "description": "Service",
#                     "name": "Service",
#                     "negative": 77,
#                     "neutral": 12,
#                     "positive": 235,
#                     "total_mentioned": 324
#                 },
#                 {
#                     "description": "Property",
#                     "name": "Property",
#                     "negative": 68,
#                     "neutral": 13,
#                     "positive": 195,
#                     "total_mentioned": 276
#                 },
#                 {
#                     "description": "Bar or lounge",
#                     "name": "Bar",
#                     "negative": 17,
#                     "neutral": 3,
#                     "positive": 67,
#                     "total_mentioned": 87
#                 },
#                 {
#                     "description": "Food and Beverage",
#                     "name": "Dining",
#                     "negative": 23,
#                     "neutral": 3,
#                     "positive": 69,
#                     "total_mentioned": 95
#                 },
#                 {
#                     "description": "Bathroom and toiletries",
#                     "name": "Bathroom",
#                     "negative": 40,
#                     "neutral": 4,
#                     "positive": 64,
#                     "total_mentioned": 108
#                 },
#                 {
#                     "description": "Cleanliness",
#                     "name": "Cleanliness",
#                     "negative": 30,
#                     "neutral": 4,
#                     "positive": 90,
#                     "total_mentioned": 124
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChoIh8OzyoXq9PqOARoNL2cvMTFkZmgzNnJtMBAB&q=Vail",
#             "type": "hotel"
#         },
#         {
#             "amenities": [
#                 "Free Wi-Fi",
#                 "Free parking",
#                 "Outdoor pool",
#                 "Hot tub",
#                 "Air conditioning",
#                 "Fitness centre",
#                 "Spa",
#                 "Restaurant",
#                 "Kitchen in rooms",
#                 "Full-service laundry",
#                 "Accessible",
#                 "Child-friendly",
#                 "Smoke-free property"
#             ],
#             "check_in_time": "4:00\u202fPM",
#             "check_out_time": "10:00\u202fAM",
#             "description": "Warm villas with balconies & mountain views in a sophisticated resort featuring an outdoor pool.",
#             "extracted_hotel_class": 5,
#             "gps_coordinates": {
#                 "latitude": 39.6426671,
#                 "longitude": -106.393198
#             },
#             "hotel_class": "5-star hotel",
#             "images": [
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/60000000/59010000/59006800/59006735/dadd2b6c_z.jpg",
#                     "thumbnail": "https://lh4.googleusercontent.com/proxy/Nncv5HnAYLjqtnjm8VmteWaSR1k-GJTWp8ZndzzrMx4CTePf3k8ehycMgn4YqZjSEhp_CfHmtt7Lyy4WG7MJ3SMEOyo09I6MnaCwK5EzhtgYf6oxfI2vwvg8byNRhHAePE6rWXqiputIMYQI-Jg_Kn6ZzrKJWFc=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/60000000/59010000/59006800/59006735/624e136a_z.jpg",
#                     "thumbnail": "https://lh6.googleusercontent.com/proxy/t4r8z0YbofLdYumGDo_gYaZ2H6C5dG9xqC9haqT3H4Q3IYAua4s4E3CzRcqzOL86A8Y5bkdhaqwUZ9wWnnEWhcxmQOx1cMJnctfkgeWFihPIr4tPMWb_zv41Uy2Q2WMGu0m-magj5n9HxJYzdcCgdS_8pVtPYF0=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/49/d4/a8/ritz-carlton-club-vail.jpg?w=2100&h=800&s=1",
#                     "thumbnail": "https://lh4.googleusercontent.com/proxy/XuHJolXp4w-mQa0B9n3GgIEU2suNveqETX8FTAW4GAQZirjDX2e5vgcEpoZnZBaNY97Tn9lZ8-iJKk9TlNZnzNzOzTicvtBetBDyXeOo5dzwX56exN-Or0VsEIWhhgvNynNItBkUv_A9-bsOw4YHiBSD1ivzRg=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMSR_GE_PSEAh3va2LHazLU0sYwVDkaZAeGrAuU=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMSR_GE_PSEAh3va2LHazLU0sYwVDkaZAeGrAuU=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/74000000/73120000/73117900/73117830/4930e45a_z.jpg",
#                     "thumbnail": "https://lh6.googleusercontent.com/proxy/ofbYIsZ3JC6ZqE96wKWstRl7r-JvwA8Jlogn9rA_4YyQ9PHX4RRQ_m5vrmqRr3foAnVZb3er2YAUDhhxyUP9qsG5AeqsHbGgJgW-TfaXmrsCpq5RfUcDxr2MRUceb0tDS0Qb1D4rLHWUUeQXNtpL9pns-py8GQ=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipP783cSJ86rC3enuR2GsYnPN6B95S0diPajrIfs=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipP783cSJ86rC3enuR2GsYnPN6B95S0diPajrIfs=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/60000000/59010000/59006800/59006735/c18b2c54_z.jpg",
#                     "thumbnail": "https://lh4.googleusercontent.com/proxy/re1R2D1HJdL8JmtddB1v2ApVLPiS0fl-T93FJARL79Qy5R6_Luyr6pfigrcWQPvDzfcgwcKrNth8Y_bNhXARc0Rprz2fID6taIB1KJUapzjeYQkvlJ8YnEA0tlMpCk04h2b0m2Lo0i5-Ix-lBm_l7s8B3Sej_R0=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/8a/5c/33/view-from-villa.jpg?w=1900&h=1400&s=1",
#                     "thumbnail": "https://lh6.googleusercontent.com/proxy/cXnXtLkE_M-FPZEHxGOvgL7H8oUq_G1exfFlF41MRG5xAU2Kl8W8CJXVv1-548OiVwQaRNHiWcnBg2hgtK-Fo2tSx03ZLM-mkHA-BLf6xSnP1r9zNcS6HSJ7G8_GV_3K3dItvyJXySi3i_CQxWi7-TyvEqVOpWI=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/93000000/92960000/92953000/92952920/274a8a03_z.jpg",
#                     "thumbnail": "https://lh4.googleusercontent.com/proxy/NUr4maWSHA8qSE53hph1WLJckjcvBiStNvAeZVnsT-dlH068uArhdoDd0af6OB2BgbEDju7L753DBSabOuD7oeqaD3gxTtK6-wfMyVtfGlF6aE7xZp9nouvgWFbuwrlyXR_YwYd2_soXa8E6rgjls0KFGoqmCA=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://www.ritzcarlton.com/en/hotels/whrlh-the-ritz-carlton-club-vail/overview/?scid=f2ae0541-1279-4f24-b197-a979c79310b0",
#             "location_rating": 3.7,
#             "name": "The Ritz-Carlton Club, Vail",
#             "nearby_places": [
#                 {
#                     "name": "Vail Ski Resort",
#                     "transportations": [
#                         {
#                             "duration": "8 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "The Hythe",
#                     "transportations": [
#                         {
#                             "duration": "1 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Aspen/Pitkin County Airport",
#                     "transportations": [
#                         {
#                             "duration": "1 hr 47 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "3 hr 25 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "The Little Diner",
#                     "transportations": [
#                         {
#                             "duration": "4 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.7,
#             "property_token": "ChgI5Omey5K67eAmGgwvZy8xeWw0OHgyY3MQAQ",
#             "ratings": [
#                 {
#                     "count": 302,
#                     "stars": 5
#                 },
#                 {
#                     "count": 25,
#                     "stars": 4
#                 },
#                 {
#                     "count": 7,
#                     "stars": 3
#                 },
#                 {
#                     "count": 3,
#                     "stars": 2
#                 },
#                 {
#                     "count": 16,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 353,
#             "reviews_breakdown": [
#                 {
#                     "description": "Service",
#                     "name": "Service",
#                     "negative": 17,
#                     "neutral": 4,
#                     "positive": 88,
#                     "total_mentioned": 109
#                 },
#                 {
#                     "description": "Property",
#                     "name": "Property",
#                     "negative": 3,
#                     "neutral": 6,
#                     "positive": 61,
#                     "total_mentioned": 70
#                 },
#                 {
#                     "description": "Parking",
#                     "name": "Parking",
#                     "negative": 4,
#                     "neutral": 0,
#                     "positive": 16,
#                     "total_mentioned": 20
#                 },
#                 {
#                     "description": "Nature and outdoor activities",
#                     "name": "Nature",
#                     "negative": 1,
#                     "neutral": 2,
#                     "positive": 22,
#                     "total_mentioned": 25
#                 },
#                 {
#                     "description": "Bar or lounge",
#                     "name": "Bar",
#                     "negative": 6,
#                     "neutral": 1,
#                     "positive": 6,
#                     "total_mentioned": 13
#                 },
#                 {
#                     "description": "Family friendly",
#                     "name": "Family",
#                     "negative": 2,
#                     "neutral": 2,
#                     "positive": 11,
#                     "total_mentioned": 15
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChgI5Omey5K67eAmGgwvZy8xeWw0OHgyY3MQAQ&q=Vail",
#             "type": "hotel"
#         },
#         {
#             "amenities": [
#                 "Breakfast ($)",
#                 "Free Wi-Fi",
#                 "Parking ($)",
#                 "Pools",
#                 "Hot tub",
#                 "Air conditioning",
#                 "Fitness centre",
#                 "Spa",
#                 "Bar",
#                 "Restaurant",
#                 "Room service",
#                 "Airport shuttle",
#                 "Golf",
#                 "Full-service laundry",
#                 "Accessible",
#                 "Business centre",
#                 "Child-friendly",
#                 "Smoke-free property"
#             ],
#             "check_in_time": "4:00\u202fPM",
#             "check_out_time": "11:00\u202fAM",
#             "description": "Upscale quarters near the ski slopes with 4 restaurants, a golf course, & a spa with 2 pools.",
#             "extracted_hotel_class": 4,
#             "gps_coordinates": {
#                 "latitude": 39.6419092,
#                 "longitude": -106.3780286
#             },
#             "hotel_class": "4-star hotel",
#             "images": [
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNH2ksSkKPCNx3lZ2giVNO1YmRTdRkvu1WHwqUA=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNH2ksSkKPCNx3lZ2giVNO1YmRTdRkvu1WHwqUA=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/2/0/72/784/321/Summer_R.jpg",
#                     "thumbnail": "https://lh3.googleusercontent.com/proxy/2nOjjmmkvxxxqcs6irqPDXt1ED0_-nowAk2kMpHZaa1-XmfUH5JNUSi5au7iCsYShinVxcxKVR7fC_tAOYvMS4Pfxev9Mt1779C7JUApjL_fGrhaNUe9ZCV1VQWYdqiWpeKNWMcMJJNCnuOenCxsX_87tPyJRg=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/6/0/86/848/272/OWB_room_P.jpg",
#                     "thumbnail": "https://lh5.googleusercontent.com/proxy/CHyVbmR3CdUdMBzqbm1cEiddPcv9Ic8qshhmG2-g4ypA-Zjemuv1wgY7ME6BiTb_GdfYPv3YQGU35UFnU_d30rVLODfTMm8Ei1tpzoCYipujeFui36QItfvLZzSjHBFsRs9XQ6HCvhnKy2gBdykUW0f_AlIdzz0=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOC-cCTzbsTiuXqmo8QdkZlwMoyt2Ukg25kE8FG=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOC-cCTzbsTiuXqmo8QdkZlwMoyt2Ukg25kE8FG=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipM5VCBUkShvxJmiAt6R7ZG1fGqZJXniPpLcua9E=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipM5VCBUkShvxJmiAt6R7ZG1fGqZJXniPpLcua9E=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMnepdFPQGtnwZHpqADZ5-qu8QzqjqWCxn1nE5m=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMnepdFPQGtnwZHpqADZ5-qu8QzqjqWCxn1nE5m=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNu7mbkXurAnSIkDPNat-WWGTE_yLMifZ0ueea6=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNu7mbkXurAnSIkDPNat-WWGTE_yLMifZ0ueea6=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipMs0-Wrv1vYn99S07mcGaXvQqJN3jjTLIG4t3Mo=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipMs0-Wrv1vYn99S07mcGaXvQqJN3jjTLIG4t3Mo=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOTiRQ6HZaPiF5TSsNl9tO-ZhOQ7-T4GSM8Vt59=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOTiRQ6HZaPiF5TSsNl9tO-ZhOQ7-T4GSM8Vt59=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://sonnenalp.com/?utm_source=local-listings&utm_medium=organic&utm_campaign=local-listings",
#             "location_rating": 4.7,
#             "name": "Sonnenalp Vail",
#             "nearby_places": [
#                 {
#                     "name": "Colorado Snowsports Museum and Hall of Fame",
#                     "transportations": [
#                         {
#                             "duration": "6 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Vail Road - Eastbound",
#                     "transportations": [
#                         {
#                             "duration": "1 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Aspen/Pitkin County Airport",
#                     "transportations": [
#                         {
#                             "duration": "1 hr 46 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "3 hr 19 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Swiss Chalet Restaurant",
#                     "transportations": [
#                         {
#                             "duration": "1 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.6,
#             "property_token": "ChcIjfP9_5nQmPIqGgsvZy8xdGoyamNxbBAB",
#             "ratings": [
#                 {
#                     "count": 653,
#                     "stars": 5
#                 },
#                 {
#                     "count": 104,
#                     "stars": 4
#                 },
#                 {
#                     "count": 33,
#                     "stars": 3
#                 },
#                 {
#                     "count": 12,
#                     "stars": 2
#                 },
#                 {
#                     "count": 21,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 823,
#             "reviews_breakdown": [
#                 {
#                     "description": "Service",
#                     "name": "Service",
#                     "negative": 16,
#                     "neutral": 5,
#                     "positive": 204,
#                     "total_mentioned": 225
#                 },
#                 {
#                     "description": "Wellness",
#                     "name": "Wellness",
#                     "negative": 4,
#                     "neutral": 3,
#                     "positive": 67,
#                     "total_mentioned": 74
#                 },
#                 {
#                     "description": "Couple friendly",
#                     "name": "Couples",
#                     "negative": 3,
#                     "neutral": 8,
#                     "positive": 30,
#                     "total_mentioned": 41
#                 },
#                 {
#                     "description": "Spa",
#                     "name": "Spa",
#                     "negative": 3,
#                     "neutral": 1,
#                     "positive": 51,
#                     "total_mentioned": 55
#                 },
#                 {
#                     "description": "Property",
#                     "name": "Property",
#                     "negative": 13,
#                     "neutral": 10,
#                     "positive": 179,
#                     "total_mentioned": 202
#                 },
#                 {
#                     "description": "Food and Beverage",
#                     "name": "Dining",
#                     "negative": 6,
#                     "neutral": 8,
#                     "positive": 68,
#                     "total_mentioned": 82
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChcIjfP9_5nQmPIqGgsvZy8xdGoyamNxbBAB&q=Vail",
#             "type": "hotel"
#         },
#         {
#             "amenities": [
#                 "Breakfast",
#                 "Free Wi-Fi",
#                 "Parking ($)",
#                 "Outdoor pool",
#                 "Hot tub",
#                 "Air conditioning",
#                 "Pet-friendly",
#                 "Fitness centre",
#                 "Spa",
#                 "Restaurant",
#                 "Golf",
#                 "Accessible",
#                 "Child-friendly",
#                 "Smoke-free property"
#             ],
#             "check_in_time": "4:00\u202fPM",
#             "check_out_time": "11:00\u202fAM",
#             "description": "Resort near the gondola with an 11,000-sq.-ft. spa & fitness center, plus 2 heated outdoor pools.",
#             "extracted_hotel_class": 4,
#             "gps_coordinates": {
#                 "latitude": 39.6402128,
#                 "longitude": -106.37481509999999
#             },
#             "hotel_class": "4-star hotel",
#             "images": [
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipO94ikmYj0knM-gcW9BJv-6Uh-R9MfD_YZAGpH9=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipO94ikmYj0knM-gcW9BJv-6Uh-R9MfD_YZAGpH9=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/7/0/157/355/34/LAV_359_003_O.jpg",
#                     "thumbnail": "https://lh4.googleusercontent.com/proxy
min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.4,
#             "property_token": "ChgIsNXKzIqK7IMVGgwvZy8xaGM3endiNDUQAQ",
#             "ratings": [
#                 {
#                     "count": 434,
#                     "stars": 5
#                 },
#                 {
#                     "count": 122,
#                     "stars": 4
#                 },
#                 {
#                     "count": 35,
#                     "stars": 3
#                 },
#                 {
#                     "count": 27,
#                     "stars": 2
#                 },
#                 {
#                     "count": 34,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 652,
#             "reviews_breakdown": [
#                 {
#                     "description": "Service",
#                     "name": "Service",
#                     "negative": 30,
#                     "neutral": 10,
#                     "positive": 135,
#                     "total_mentioned": 175
#                 },
#                 {
#                     "description": "Property",
#                     "name": "Property",
#                     "negative": 44,
#                     "neutral": 11,
#                     "positive": 118,
#                     "total_mentioned": 173
#                 },
#                 {
#                     "description": "Parking",
#                     "name": "Parking",
#                     "negative": 24,
#                     "neutral": 6,
#                     "positive": 14,
#                     "total_mentioned": 44
#                 },
#                 {
#                     "description": "Location",
#                     "name": "Location",
#                     "negative": 9,
#                     "neutral": 10,
#                     "positive": 90,
#                     "total_mentioned": 109
#                 },
#                 {
#                     "description": "Room amenities",
#                     "name": "Room",
#                     "negative": 26,
#                     "neutral": 6,
#                     "positive": 23,
#                     "total_mentioned": 55
#                 },
#                 {
#                     "description": "Bathroom and toiletries",
#                     "name": "Bathroom",
#                     "negative": 19,
#                     "neutral": 0,
#                     "positive": 24,
#                     "total_mentioned": 43
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChgIsNXKzIqK7IMVGgwvZy8xaGM3endiNDUQAQ&q=Vail",
#             "type": "hotel"
#         },
#         {
#             "amenities": [
#                 "Breakfast ($)",
#                 "Wi-Fi",
#                 "Parking ($)",
#                 "Outdoor pool",
#                 "Hot tub",
#                 "Air conditioning",
#                 "Pet-friendly",
#                 "Fitness centre",
#                 "Spa",
#                 "Bar",
#                 "Restaurant",
#                 "Room service",
#                 "Kitchen in some rooms",
#                 "Full-service laundry",
#                 "Accessible",
#                 "Business centre",
#                 "Child-friendly",
#                 "Smoke-free property"
#             ],
#             "check_in_time": "4:00\u202fPM",
#             "check_out_time": "11:00\u202fAM",
#             "description": "Polished quarters, some with kitchens, in a posh hotel offering dining, an outdoor pool & a spa.",
#             "extracted_hotel_class": 4,
#             "gps_coordinates": {
#                 "latitude": 39.642575799999996,
#                 "longitude": -106.37800589999999
#             },
#             "hotel_class": "4-star hotel",
#             "images": [
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOHBWHbf09r3y2WzcCPsgZiNT7D36dZgMrLx7SN=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOHBWHbf09r3y2WzcCPsgZiNT7D36dZgMrLx7SN=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOOUritxDJV1byL8fN7voMPHOpeb9Iy_Z45l3sW=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOOUritxDJV1byL8fN7voMPHOpeb9Iy_Z45l3sW=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOOYCBoKnOxkCjucWgB-rL_11iIBEY4uA4_Djin=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOOYCBoKnOxkCjucWgB-rL_11iIBEY4uA4_Djin=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/80000000/79850000/79845300/79845281/w1600h1073x0y3-018d0f2a_z.jpg",
#                     "thumbnail": "https://lh6.googleusercontent.com/proxy/SeYc-IIFtzs4yJKzPyGaZ2RjMs_tq_uNBgJ8x1auyQC_97VE0zPl1Qde_dQNpsnaItBTKwzdHvtr2ecNLQ6yGAjEJkHTvj5aKo62X0ni2JiSgcIRbjYF7mAJauUsfARESz3fQvYDrqK6u_v_a_vVOvHIYjzKt7I=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/aWkD62GWLQgAAAQqf4pkqg=s10000",
#                     "thumbnail": "https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=aWkD62GWLQgAAAQqf4pkqg&cb_client=search.estubs.gps&w=287&h=192&yaw=40&pitch=0&thumbfov=100&scale=2"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOhdDbvhTRDylr7JXmZC8RRZtjHmK_q6pkrwpWP=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOhdDbvhTRDylr7JXmZC8RRZtjHmK_q6pkrwpWP=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/LU53_62UGkUAAAQqf4nq_g=s10000",
#                     "thumbnail": "https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=LU53_62UGkUAAAQqf4nq_g&cb_client=search.estubs.gps&w=287&h=192&yaw=300&pitch=-10&thumbfov=100&scale=2"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipPiFqiHRqPvUHt7QfzZyjKPk3QxvbqEJt5-HoL1=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPiFqiHRqPvUHt7QfzZyjKPk3QxvbqEJt5-HoL1=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNyn_TZXm5F_S0xO1FAr87doMM4oTwH2AzKz_o6=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNyn_TZXm5F_S0xO1FAr87doMM4oTwH2AzKz_o6=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://www.thesebastianvail.com/?utm_source=Google&utm_medium=Yext",
#             "location_rating": 4.7,
#             "name": "The Sebastian - Vail",
#             "nearby_places": [
#                 {
#                     "name": "Colorado Snowsports Museum and Hall of Fame",
#                     "transportations": [
#                         {
#                             "duration": "7 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Vail Road - Eastbound",
#                     "transportations": [
#                         {
#                             "duration": "1 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Aspen/Pitkin County Airport",
#                     "transportations": [
#                         {
#                             "duration": "1 hr 46 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "3 hr 19 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Bully Ranch Restaurant",
#                     "transportations": [
#                         {
#                             "duration": "2 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.6,
#             "property_token": "ChgIya-byKyrifa_ARoLL2cvMXRqMm55ejYQAQ",
#             "ratings": [
#                 {
#                     "count": 389,
#                     "stars": 5
#                 },
#                 {
#                     "count": 52,
#                     "stars": 4
#                 },
#                 {
#                     "count": 23,
#                     "stars": 3
#                 },
#                 {
#                     "count": 7,
#                     "stars": 2
#                 },
#                 {
#                     "count": 19,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 490,
#             "reviews_breakdown": [
#                 {
#                     "description": "Service",
#                     "name": "Service",
#                     "negative": 21,
#                     "neutral": 5,
#                     "positive": 134,
#                     "total_mentioned": 160
#                 },
#                 {
#                     "description": "Property",
#                     "name": "Property",
#                     "negative": 19,
#                     "neutral": 5,
#                     "positive": 120,
#                     "total_mentioned": 144
#                 },
#                 {
#                     "description": "Wellness",
#                     "name": "Wellness",
#                     "negative": 5,
#                     "neutral": 1,
#                     "positive": 15,
#                     "total_mentioned": 21
#                 },
#                 {
#                     "description": "Parking",
#                     "name": "Parking",
#                     "negative": 8,
#                     "neutral": 1,
#                     "positive": 14,
#                     "total_mentioned": 23
#                 },
#                 {
#                     "description": "Spa",
#                     "name": "Spa",
#                     "negative": 4,
#                     "neutral": 1,
#                     "positive": 12,
#                     "total_mentioned": 17
#                 },
#                 {
#                     "description": "Location",
#                     "name": "Location",
#                     "negative": 4,
#                     "neutral": 4,
#                     "positive": 72,
#                     "total_mentioned": 80
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=
s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://images.trvl-media.com/lodging/1000000/910000/900500/900407/ad6bb7d5_z.jpg",
#                     "thumbnail": "https://lh5.googleusercontent.com/proxy/xBlr3hXgftyUyvaaZcK3EwtQROQbXMsPc0nsXAQ3IWAF3G9-lVapXIUiU2jiFKhaUSu_MyajMzrA85noaLECe9uGzZMEa8P9v-_Inm26aNs3F9WGCkp9LW4AL8U1jJfC00qHEB071tx4-sLVKDrtaR7on4jTSw=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://tivolilodge.com/",
#             "location_rating": 4.7,
#             "name": "Tivoli Lodge",
#             "nearby_places": [
#                 {
#                     "name": "Gondola One",
#                     "transportations": [
#                         {
#                             "duration": "3 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Hanson Ranch Road",
#                     "transportations": [
#                         {
#                             "duration": "1 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Aspen/Pitkin County Airport",
#                     "transportations": [
#                         {
#                             "duration": "1 hr 49 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "3 hr 17 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Big Bear Bistro",
#                     "transportations": [
#                         {
#                             "duration": "2 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.4,
#             "property_token": "ChgIz5rYh8fu4o_6ARoLL2cvMXZjODI5MWQQAQ",
#             "rate_per_night": {
#                 "before_taxes_fees": "$1,666",
#                 "extracted_before_taxes_fees": 1666,
#                 "extracted_lowest": 1896,
#                 "lowest": "$1,896"
#             },
#             "ratings": [
# ...
#                     "thumbnail": "https://lh3.googleusercontent.com/proxy/5v5DeD2gpQFvayuwK2FYDDskEMdhFS5mPmkOPQI-y4PFWqPyu0D8quNoxMPWazVRO3jdSAKqcb_Ddmr-WJElKkKpF1nPnxJ0l1b94kmOKjGT1HLNe58xEeX8XlukMTxdJ7MGh48_lUOhIKeYvLr4Ck2Ofqz5onQ=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/09/39/6d/57/photo2jpg.jpg?w=1900&h=1400&s=1",
#                     "thumbnail": "https://lh3.googleusercontent.com/proxy/fO61O0q8A08rR37APiDA0ZNqBHLyatkpW6H6c1eoyn9zuvXRP8PPmw66jqt0lgMFFF_sMiUIGNGHI0um_HHr7AgI1tV0zwDVt0ulDwFSliyEa2OmrMGzwsKQI6R4zzfgRrLjCuKjtEfLhfwjCqxj5ZLCV92byg=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://photos.hotelbeds.com/giata/original/36/366805/366805a_hb_r_003.jpg",
#                     "thumbnail": "https://lh3.googleusercontent.com/proxy/UBYCX8Uyb0SH-Bl63Zi0uYKY_MIM68Ad8bU6iyqZs2DHCP0FbXKn9D0vZJdJLio40A13jceidK3T0qinkYmFainPVqNqGFH4Ccc0jjfuZDOjE1vMRqcXn2T_p9SgoJpBC3sLxFHUGGDQs4MusFPLcvYTCBLn0A=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://photos.hotelbeds.com/giata/original/36/366805/366805a_hb_l_003.jpg",
#                     "thumbnail": "https://lh3.googleusercontent.com/proxy/kglqDMZrL3KEX9QCa43ZJJhQl1s3raphCJZDqCXsCWXsnxTNpaKy6u6P6K8QioU9-7Sow1YxHk8l4dgTkQRe34Cr9KOsBTtBHpoZpDjI9Os8SrsL5TU8JooOE2c3QKA9l3FpHR7s8Oq0HLwnDxwpcMvrTMsotg=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://www.bestwestern.com/en_US/book/hotel-rooms.03153.html?iata=00171880&ssob=BLBWI0004G&cid=BLBWI0004G:google:gmb:03153",
#             "location_rating": 3.2,
#             "name": "Best Western Gold Poppy Inn",
#             "nearby_places": [
#                 {
#                     "name": "Ina/Starcommerce Way (NW)",
#                     "transportations": [
#                         {
#                             "duration": "8 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Tucson International Airport",
#                     "transportations": [
#                         {
#                             "duration": "26 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "2 hr 22 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Guadalajara's Grill & Tequila Bar",
#                     "transportations": [
#                         {
#                             "duration": "8 min",
#                             "type": "Taxi"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 4.1,
#             "property_token": "ChkI9dHZtrz0juT3ARoML2cvMTE5dGw3MjJxEAE",
#             "rate_per_night": {
#                 "before_taxes_fees": "$88",
#                 "extracted_before_taxes_fees": 88,
#                 "extracted_lowest": 100,
#                 "lowest": "$100"
#             },
#             "ratings": [
#                 {
#                     "count": 273,
#                     "stars": 5
#                 },
#                 {
#                     "count": 179,
#                     "stars": 4
#                 },
#                 {
#                     "count": 54,
#                     "stars": 3
#                 },
#                 {
#                     "count": 32,
#                     "stars": 2
#                 },
#                 {
#                     "count": 38,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 576,
#             "reviews_breakdown": [
#                 {
#                     "description": "Breakfast",
#                     "name": "Breakfast",
#                     "negative": 14,
#                     "neutral": 8,
#                     "positive": 93,
#                     "total_mentioned": 115
#                 },
#                 {
#                     "description": "Restaurant",
#                     "name": "Restaurant",
#                     "negative": 6,
#                     "neutral": 5,
#                     "positive": 53,
#                     "total_mentioned": 64
#                 },
#                 {
#                     "description": "Sleep",
#                     "name": "Sleep",
#                     "negative": 24,
#                     "neutral": 13,
#                     "positive": 23,
#                     "total_mentioned": 60
#                 },
#                 {
#                     "description": "Service",
#                     "name": "Service",
#                     "negative": 27,
#                     "neutral": 3,
#                     "positive": 126,
#                     "total_mentioned": 156
#                 },
#                 {
#                     "description": "Bar or lounge",
#                     "name": "Bar",
#                     "negative": 3,
#                     "neutral": 2,
#                     "positive": 11,
#                     "total_mentioned": 16
#                 },
#                 {
#                     "description": "Property",
#                     "name": "Property",
#                     "negative": 27,
#                     "neutral": 12,
#                     "positive": 119,
#                     "total_mentioned": 158
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkI9dHZtrz0juT3ARoML2cvMTE5dGw3MjJxEAE&q=Oro+Valley",
#             "total_rate": {
#                 "before_taxes_fees": "$2,552",
#                 "extracted_before_taxes_fees": 2552,
#                 "extracted_lowest": 2911,
#                 "lowest": "$2,911"
#             },
#             "type": "hotel"
#         },
#         {
#             "amenities": [
#                 "Free breakfast",
#                 "Free Wi-Fi",
#                 "Free parking",
#                 "Outdoor pool",
#                 "Hot tub",
#                 "Air conditioning",
#                 "Pet-friendly",
#                 "Fitness centre",
#                 "Full-service laundry",
#                 "Accessible",
#                 "Business centre",
#                 "Child-friendly",
#                 "Smoke-free property"
#             ],
#             "check_in_time": "3:00\u202fPM",
#             "check_out_time": "12:00\u202fPM",
#             "description": "Casual property with an outdoor pool, hot tub & gym, plus free breakfast, WiFi & parking.",
#             "extracted_hotel_class": 2,
#             "gps_coordinates": {
#                 "latitude": 32.220279399999995,
#                 "longitude": -110.8558973
#             },
#             "hotel_class": "2-star hotel",
#             "images": [
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipM6vIhXcDZmUGvvh3qrtrMwSVIdZ97fYf58zHrV=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipM6vIhXcDZmUGvvh3qrtrMwSVIdZ97fYf58zHrV=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOfOuxF24yq8k3j1GMCI2SAE1jV6yQAERrdMVNh=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOfOuxF24yq8k3j1GMCI2SAE1jV6yQAERrdMVNh=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNxreCRzQnW4nCAtxiFMRS5mvoUbdHSKafPeBNd=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNxreCRzQnW4nCAtxiFMRS5mvoUbdHSKafPeBNd=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNx4OxCR8ZFUK6Gddgo1_rwETgjHd4lsFbNmbJR=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNx4OxCR8ZFUK6Gddgo1_rwETgjHd4lsFbNmbJR=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOzBe1LTnTITYfQYyO2t9zJzTzQziE0hL8kZyT3=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOzBe1LTnTITYfQYyO2t9zJzTzQziE0hL8kZyT3=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNt5eOHd_STUkUuCpbhpkhi30jURXfDTpAHYjRG=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNt5eOHd_STUkUuCpbhpkhi30jURXfDTpAHYjRG=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipPDilrXo4Y7lujUwvlQKaHsoq96C3dkzx6Q6VEy=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipPDilrXo4Y7lujUwvlQKaHsoq96C3dkzx6Q6VEy=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipNST79kk14xkOr3ia7rdgP7YW7_BhskZEmJIo6K=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipNST79kk14xkOr3ia7rdgP7YW7_BhskZEmJIo6K=s287-w287-h192-n-k-no-v1"
#                 },
#                 {
#                     "original_image": "https://lh5.googleusercontent.com/p/AF1QipOQS8VSIp0Sb5CjgN9UGVx0TF6HZXUKs8exPonV=s10000",
#                     "thumbnail": "https://lh5.googleusercontent.com/p/AF1QipOQS8VSIp0Sb5CjgN9UGVx0TF6HZXUKs8exPonV=s287-w287-h192-n-k-no-v1"
#                 }
#             ],
#             "link": "https://www.wyndhamhotels.com/laquinta/tucson-arizona/la-quinta-inn-tucson-east/overview?CID=LC:6ysy27krtpcrqev:52786&iata=00093796",
#             "location_rating": 4.2,
#             "name": "La Quinta Inn by Wyndham Tucson East",
#             "nearby_places": [
#                 {
#                     "name": "Trail Dust Town",
#                     "transportations": [
#                         {
#                             "duration": "7 min",
#                             "type": "Taxi"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Broadway/Wilmot (SE)",
#                     "transportations": [
#                         {
#                             "duration": "3 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Tucson International Airport",
#                     "transportations": [
#                         {
#                             "duration": "24 min",
#                             "type": "Taxi"
#                         },
#                         {
#                             "duration": "1 hr 14 min",
#                             "type": "Public transport"
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Raising Cane's Chicken Fingers",
#                     "transportations": [
#                         {
#                             "duration": "2 min",
#                             "type": "Walking"
#                         }
#                     ]
#                 }
#             ],
#             "overall_rating": 3.5,
#             "property_token": "ChcI77SB8_6cnao0GgsvZy8xeGd6YzZwORAB",
#             "rate_per_night": {
#                 "before_taxes_fees": "$67",
#                 "extracted_before_taxes_fees": 67,
#                 "extracted_lowest": 79,
#                 "lowest": "$79"
#             },
#             "ratings": [
#                 {
#                     "count": 629,
#                     "stars": 5
#                 },
#                 {
#                     "count": 412,
#                     "stars": 4
#                 },
#                 {
#                     "count": 265,
#                     "stars": 3
#                 },
#                 {
#                     "count": 152,
#                     "stars": 2
#                 },
#                 {
#                     "count": 283,
#                     "stars": 1
#                 }
#             ],
#             "reviews": 1741,
#             "reviews_breakdown": [
#                 {
#                     "description": "Pets",
#                     "name": "Pets",
#                     "negative": 14,
#                     "neutral": 5,
#                     "positive": 38,
#                     "total_mentioned": 57
#                 },
#                 {
#                     "description": "Breakfast",
#                     "name": "Breakfast",
#                     "negative": 40,
#                     "neutral": 14,
#                     "positive": 106,
#                     "total_mentioned": 160
#                 },
#                 {
#                     "description": "Bathroom and toiletries",
#                     "name": "Bathroom",
#                     "negative": 166,
#                     "neutral": 17,
#                     "positive": 29,
#                     "total_mentioned": 212
#                 },
#                 {
#                     "description": "Cleanliness",
#                     "name": "Cleanliness",
#                     "negative": 190,
#                     "neutral": 22,
#                     "positive": 204,
#                     "total_mentioned": 416
#                 },
#                 {
#                     "description": "Restaurant",
#                     "name": "Restaurant",
#                     "negative": 23,
#                     "neutral": 8,
#                     "positive": 61,
#                     "total_mentioned": 92
#                 },
#                 {
#                     "description": "Fitness",
#                     "name": "Fitness",
#                     "negative": 30,
#                     "neutral": 7,
#                     "positive": 65,
#                     "total_mentioned": 102
#                 }
#             ],
#             "serpapi_property_details_link": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChcI77SB8_6cnao0GgsvZy8xeGd6YzZwORAB&q=Oro+Valley",
#             "total_rate": {
#                 "before_taxes_fees": "$1,946",
#                 "extracted_before_taxes_fees": 1946,
#                 "extracted_lowest": 2297,
#                 "lowest": "$2,297"
#             },
#             "type": "hotel"
#         }
#     ],
#     "search_information": {
#         "total_results": 4248
#     },
#     "search_metadata": {
#         "created_at": "2024-11-24 22:27:50 UTC",
#         "google_hotels_url": "https://www.google.com/_/TravelFrontendUi/data/batchexecute?rpcids=AtySUc&source-path=/travel/search&hl=en&gl=us&rt=c&soc-app=162&soc-platform=1&soc-device=1",
#         "id": "6743a866213c87eab0476c60",
#         "json_endpoint": "https://serpapi.com/searches/c81d8bf27eb7b5cf/6743a866213c87eab0476c60.json",
#         "prettify_html_file": "https://serpapi.com/searches/c81d8bf27eb7b5cf/6743a866213c87eab0476c60.prettify",
#         "processed_at": "2024-11-24 22:27:50 UTC",
#         "raw_html_file": "https://serpapi.com/searches/c81d8bf27eb7b5cf/6743a866213c87eab0476c60.html",
#         "status": "Success",
#         "total_time_taken": 1.69
#     },
#     "search_parameters": {
#         "adults": 2,
#         "check_in_date": "2024-12-03",
#         "check_out_date": "2025-01-01",
#         "children": 0,
#         "currency": "USD",
#         "engine": "google_hotels",
#         "gl": "us",
#         "hl": "en",
#         "q": "Oro Valley"
#     },
#     "serpapi_pagination": {
#         "current_from": 1,
#         "current_to": 20,
#         "next": "https://serpapi.com/search.json?adults=2&check_in_date=2024-12-03&check_out_date=2025-01-01&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&next_page_token=CBI%3D&q=Oro+Valley",
#         "next_page_token": "CBI="
#     }
# }

# %%
# Create dataframe that has the hotel, longitude, latitude, location rating, overall rating,
# ratings, reviews, reviews breakdown, hotel class, link

hotels = response.json()

# %%
properties = hotels['properties']
print(properties)

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))


print(name)
print(description)
print(coordinates)
print(hotel_class)
print(link)
print(ratings)
print(reviews)
print(reviews_breakdown)
# Out:
 4, 'neutral': 2}, {'name': 'Cleanliness', 'description': 'Cleanliness', 'total_mentioned': 69, 'positive': 48, 'negative': 21, 'neutral': 0}, {'name': 'Property', 'description': 'Property', 'total_mentioned': 81, 'positive': 50, 'negative': 23, 'neutral': 8}], [{'name': 'Nature', 'description': 'Nature and outdoor activities', 'total_mentioned': 176, 'positive': 167, 'negative': 4, 'neutral': 5}, {'name': 'Wellness', 'description': 'Wellness', 'total_mentioned': 64, 'positive': 46, 'negative': 10, 'neutral': 8}, {'name': 'Couples', 'description': 'Couple friendly', 'total_mentioned': 55, 'positive': 43, 'negative': 3, 'neutral': 9}, {'name': 'Nightlife', 'description': 'Nightlife', 'total_mentioned': 54, 'positive': 37, 'negative': 5, 'neutral': 12}, {'name': 'Spa', 'description': 'Spa', 'total_mentioned': 43, 'positive': 32, 'negative': 8, 'neutral': 3}, {'name': 'Pets', 'description': 'Pets', 'total_mentioned': 16, 'positive': 8, 'negative': 6, 'neutral': 2}], [{'name': 'Kitchen', 'description': 'Kitchen', 'total_mentioned': 83, 'positive': 51, 'negative': 25, 'neutral': 7}, {'name': 'Pets', 'description': 'Pets', 'total_mentioned': 21, 'positive': 8, 'negative': 11, 'neutral': 2}, {'name': 'Location', 'description': 'Location', 'total_mentioned': 83, 'positive': 62, 'negative': 12, 'neutral': 9}, {'name': 'Cleanliness', 'description': 'Cleanliness', 'total_mentioned': 214, 'positive': 144, 'negative': 60, 'neutral': 10}, {'name': 'Service', 'description': 'Service', 'total_mentioned': 279, 'positive': 214, 'negative': 51, 'neutral': 14}, {'name': 'Breakfast', 'description': 'Breakfast', 'total_mentioned': 35, 'positive': 12, 'negative': 20, 'neutral': 3}], [{'name': 'Bar', 'description': 'Bar or lounge', 'total_mentioned': 191, 'positive': 108, 'negative': 62, 'neutral': 21}, {'name': 'Service', 'description': 'Service', 'total_mentioned': 822, 'positive': 574, 'negative': 199, 'neutral': 49}, {'name': 'Property', 'description': 'Property', 'total_mentioned': 901, 'positive': 634, 'negative': 199, 'neutral': 68}, {'name': 'Business', 'description': 'Bu ...

# %%
import pandas as pd
# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "az_hotels_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to az_hotels_data.csv

# %% [markdown]
# CA Hotels

# %%
import requests
import json
import pandas as pd

# %%
# API key
api_key = "b3b0205c59ba7f49f3c156e6a208fc2a8d4d77dfa47462528f58ecfbc48ad059"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Santa Barbara']
#city = ['Goleta']
#city = ['Carpinteria']
#city = ['Isla Vista']
city = ['Montecito']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "ca_hotels5_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to ca_hotels5_data.csv

# %% [markdown]
# Delaware cities

# %%
# API key
api_key = "b3b0205c59ba7f49f3c156e6a208fc2a8d4d77dfa47462528f58ecfbc48ad059"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Claymont']
#city = ['Wilmington']
#city = ['New Castle']
#city = ['Newark']
city = ['Hockessin']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "de_hotels5_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to de_hotels5_data.csv

# %% [markdown]
# Florida Cities

# %%
# API key
api_key = "bcfbeaa7a45c637ab72fdfcd6562808f3e71766b34d9bf959c773cfd01f01872"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Tampa']
#city = ['St. Petersburg']
#city = ['Clearwater']
#city = ['Brandon']
#city = ['Lutz']
#city = ['Riverview']
#city = ['Seffner']
#city = ['Largo']
#city = ['Clearwater']
#city = ['Valrico']
#city = ['Wesley Chapel']
#city = ['Apollo Beach']
#city = ['New Port Richey']
#city = ['Spring Hill']
#city = ['Palm Harbor']
#city = ['Dunedin']
#city = ['Plant City']
#city = ['Ruskin']
#city = ['Temple Terrace']
#city = ['Seminole']
#city = ['Land O Lakes']
#city = ['Trinity']
#city = ['Hudson']
#city = ['Lithia']
#city = ['Madeira Beach']
#city = ['Oldsmar']
#city = ['Zephyrhills']
#city = ['Odessa']
#city = ['Gulfport']
#city = ['Belleair Bluffs']
city = ['Indian Rocks Beach']


# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "fl_hotels30_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to fl_hotels30_data.csv

# %% [markdown]
# Idaho Cities

# %%
# API key
api_key = "bcfbeaa7a45c637ab72fdfcd6562808f3e71766b34d9bf959c773cfd01f01872"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Boise']
#city = ['Meridian']
#city = ['Garden City']
city = ['Eagle']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "id_hotels4_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to id_hotels4_data.csv

# %% [markdown]
# Illinois Cities

# %%
# API key
api_key = "bcfbeaa7a45c637ab72fdfcd6562808f3e71766b34d9bf959c773cfd01f01872"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Alton']
#city = ['Bellville']
#city = ['Granite City']
#city = ['Wood River']
#city = ['Swansea']
#city = ['Maryville']
#city = ['Edwardsville']
#city = ['Glen Carbon']
#city = ['Cahokia']
#city = ['Fairview Heights']
#city = ['Caseyville']
#city = ['Collinsville']
#city = ['Columbia IL']
#city = ['Millstad']
#city = ['O Fallon']
#city = ['Troy IL']
#city = ['Pontoon Beach']
#city = ['Waterloo']
#city = ['Bethalto']
#city = ['Cottage Hills']
#city = ['Lebanon IL']
#city = ['East St. Louis IL']
#city = ['Washington Park']
city = ['Freeburg']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "il_hotels24_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to il_hotels24_data.csv

# %% [markdown]
# Indiana Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "c934bb0846fd14305602e13eee06ca2c80ad23933b1551f8f3436c16f81532eb"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Carmel IN']
#city = ['Fishers IN']
#city = ['Greenwood IN']
#city = ['Plainfield IN']
#city = ['Indianapolis']
#city = ['McCordsville IN']
#city = ['Whitestown IN']
#city = ['Zionsville IN']
#city = ['Brownsburg IN']
#city = ['Camby IN']
#city = ['Avon IN']
#city = ['Greenfield IN']
#city = ['Moorseville IN']
#city = ['Speedway IN']
#city = ['Noblesville IN']
#city = ['New Palestine IN']
#city = ['New Whiteland IN']
#city = ['Lawrence IN']
#city = ['Franklin IN']
#city = ['Indianapolis St']
#city = ['Beech Grove IN']
#city = ['Carmel St']
city = ['Southport IN']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "in_hotels23_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to in_hotels23_data.csv

# %% [markdown]
# Lousiana Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "c934bb0846fd14305602e13eee06ca2c80ad23933b1551f8f3436c16f81532eb"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Metairie LA']
#city = ['Metairie Blvd']
#city = ['Metairie Rd']
#city = ['Metairie 70006']
#city = ['Belle Chasse LA']
#city = ['Chalmette LA']
#city = ['Chalmette St']
#city = ['Gretna LA']
#city = ['Gretna St']
#city = ['Gretna 70056']
#city = ['Terrytown LA']
#city = ['Harvey LA']
#city = ['Kenner LA']
#city = ['Kenner St']
#city = ['Kenner Blvd']
#city = ['Kenner 70062']
#city = ['Kenner 70065']
#city = ['New Orleans LA']
#city = ['New Orleans']
#city = ['New Orleans St']
#city = ['New Orleans Ave']
#city = ['New Orleans Pl']
#city = ['New Orleans 70115']
#city = ['New Orleans 70119']
#city = ['New Orleans 70125']
#city = ['New Orleans 70130']
#city = ['New Orleans 70153']
#city = ['Marrero LA']
#city = ['Marrero St']
#city = ['Meraux LA']
#city = ['Westwego LA']
#city = ['Algiers LA']
#city = ['Jefferson LA']
#city = ['Harahan LA']
#city = ['River Ridge LA']
#city = ['Arabi LA']
city = ['Saint Rose LA']


# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "la_hotels37_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to la_hotels37_data.csv

# %% [markdown]
# Missouri Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "c934bb0846fd14305602e13eee06ca2c80ad23933b1551f8f3436c16f81532eb"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Arnold MO']
#city = ['Florissant MO']
#city = ['Florissant 63033']
#city = ['St. Louis']
#city = ['Saint Louis MO']
#city = ['St. Louis Blvd']
#city = ['St. Louis 63103']
#city = ['St. Louis 63111']
#city = ['St. Louis 63116']
#city = ['St. Louis 63125']
#city = ['St. Louis 63132']
#city = ['Earth City MO']
#city = ['Peerless Park MO']
#city = ['Shrewsburry MO']
#city = ['Normandy MO']
#city = ['Des Peres MO']
#city = ['Ferguson MO']
#city = ['St. Charles MO']
#city = ['Ballwin MO']
#city = ['Chesterfield MO']
#city = ['Fenton MO']
#city = ['Hazelwood MO']
#city = ['Bridgeton MO']
#city = ['Kirkwood MO']
#city = ['Brentwood MO']
#city = ['Maryland Heights MO']
city = ['Manchester MO']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "mo_hotels27_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to mo_hotels27_data.csv

# %% [markdown]
# New Jersey Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "c934bb0846fd14305602e13eee06ca2c80ad23933b1551f8f3436c16f81532eb"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Burlington NJ']
#city = ['Cherry Hill NJ']
#city = ['Medford NJ']
#city = ['Glassboro NJ']
#city = ['Willingboro NJ']
#city = ['Turnersville NJ']
#city = ['Pine Hill NJ']
#city = ['Mount Holly NJ']
#city = ['Moorestown NJ']
#city = ['Delran NJ']
#city = ['Woodbury NJ']
#city = ['Sicklerville NJ']
#city = ['Camden NJ']
#city = ['Pennsauken NJ']
#city = ['Trenton NJ']
#city = ['Berlin NJ']
#city = ['Voorhees NJ']
#city = ['Maple Shade NJ']
#city = ['Marlton NJ']
#city = ['Mount Laurel NJ']
#city = ['Williamstown NJ']
#city = ['Deptford NJ']
#city = ['Sewell NJ']
#city = ['Somerdale NJ']
#city = ['Ewing NJ']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "nj_hotels26_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-3d5b16399c34> in <cell line: 2>()
#       1 hotels = response.json()
# ----> 2 properties = hotels['properties']
#       3
#       4 name = []
#       5 description = []
#
# KeyError: 'properties'

# %% [markdown]
# Nevada Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "95e24167c778587fa858404d04909f63707a38b5942aa0bb5244908b7ac40994"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Reno NV']
#city = ['Reno 89501']
#city = ['Reno 89502']
#city = ['Reno 89511']
#city = ['Reno 89521']
#city = ['Reno 89523']
#city = ['Sparks NV']
#city = ['Sparks 89433']
#city = ['Sparks 89436']
#city = ['Sun Valley NV']
#city = ['Verdi NV']
city = ['Spanish Springs NV']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "nv_hotels12_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to nv_hotels12_data.csv

# %% [markdown]
# Pennsylvania Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "95e24167c778587fa858404d04909f63707a38b5942aa0bb5244908b7ac40994"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Pipersville PA']
#city = ['Philadephia']
#city = ['Wayne PA']
#city = ['Philadephia 19104']
#city = ['Philadephia 19124']
#city = ['Philadephia 19132']
#city = ['Philadephia 19144']
#city = ['Norristown PA']
#city = ['Warrington PA']
#city = ['Langhorne PA']
#city = ['Bristol PA']
#city = ['Ambler PA']
#city = ['Morrisville PA']
#city = ['Phoenixville PA']
#city = ['Pottstown PA']
#city = ['Downingtown PA']
#city = ['Warminster PA']
#city = ['Brookhaven PA']
#city = ['Bensalem PA']
#city = ['Levittown PA']
#city = ['Sprinfield PA']
#city = ['Havertown PA']
#city = ['Willow Grove PA']
#city = ['Exton PA']
#city = ['West Chester PA']
#city = ['Royersford PA']
#city = ['Doylestown PA']
#city = ['Ardmore PA']
#city = ['Chester PA']
#city = ['Lansdale PA']
#city = ['Abington PA']
#city = ['Jenkintown PA']
#city = ['Media PA']
city = ['Newtown PA']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "pa_hotels34_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to pa_hotels34_data.csv

# %% [markdown]
# Tennesee Cities

# %%
import requests
import json
import pandas as pd

# API key
api_key = "95e24167c778587fa858404d04909f63707a38b5942aa0bb5244908b7ac40994"

# Base URL for the SerpApi request
base_url = "https://serpapi.com/search.json"

#city = ['Antioch TN']
#city = ['Nashville TN']
#city = ['Nashville 37211']
#city = ['Nashville 37217']
#city = ['Hermitage TN']
#city = ['La Vergne TN']
#city = ['Smyrna TN']
#city = ['Bellvue TN']
#city = ['Brentwood TN']
#city = ['Franklin TN']
#city = ['Gallatin TN']
#city = ['Hendersonville TN']
#city = ['Goodlettsville TN']
#city = ['Mount Juliet TN']
#city = ['Madison TN']
#city = ['Pleasant View TN']
city = ['White House TN']

# Parameters for request
params = {
    "engine": "google_hotels",
    "q": city,
    "gl": "us",
    "hl": "en",
    "currency": "USD",
    "check_in_date": "2024-12-03",
    "check_out_date": "2025-01-01",
    "property_types": "12, 13, 15, 15, 17, 18, 21",
    "api_key": api_key
}

response = requests.get(base_url, params=params)

# Convert response to JSON
response_json = response.json()

# %%
hotels = response.json()
properties = hotels['properties']

name = []
description = []
coordinates = []
hotel_class = []
link = []
ratings = []
reviews = []
reviews_breakdown = []

for i in range(len(properties)):
    name.append(properties[i].get('name', 'N/A'))
    description.append(properties[i].get('description', 'N/A'))
    coordinates.append(properties[i].get('gps_coordinates', 'N/A'))
    hotel_class.append(properties[i].get('extracted_hotel_class', 'N/A'))
    link.append(properties[i].get('link', 'N/A'))
    ratings.append(properties[i].get('ratings', 'N/A'))
    reviews.append(properties[i].get('reviews', 'N/A'))
    reviews_breakdown.append(properties[i].get('reviews_breakdown', 'N/A'))

# Create a DataFrame
data = {
    'Name': name,
    'Description': description,
    'Coordinates': coordinates,
    'Hotel Class': hotel_class,
    'Link': link,
    'Ratings': ratings,
    'Reviews': reviews,
    'Reviews Breakdown': reviews_breakdown
}

df = pd.DataFrame(data)

# Export to CSV
csv_file = "tn_hotels17_data.csv"
df.to_csv(csv_file, index=False)

print(f"Data exported to {csv_file}")
# Out:
# Data exported to tn_hotels17_data.csv
